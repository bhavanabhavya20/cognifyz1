# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data= pd.read_csv("/content/dataset.csv")

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
data.shape
# Out:
# (9551, 21)

# %%
data.head(10)
# Out:
#    Restaurant ID                           Restaurant Name  Country Code  \
# 0        6317637                          Le Petit Souffle           162
# 1        6304287                          Izakaya Kikufuji           162
# 2        6300002                    Heat - Edsa Shangri-La           162
# 3        6318506                                      Ooma           162
# 4        6314302                               Sambo Kojin           162
# 5       18189371                              Din Tai Fung           162
# 6        6300781                                Buffet 101           162
# 7        6301290                                   Vikings           162
# 8        6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9        6314987                                  Locavore           162
#
#                City                                            Address  \
# 0       Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# ...

# %%
data.tail(10)
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9541        5905215           Emirgan S�_ti��           208  ��stanbul
# 9542        5926979            Leman K�_lt�_r           208  ��stanbul
# 9543        5916085              Dem Karak�_y           208  ��stanbul
# 9544        5915547     Karak�_y G�_ll�_o��lu           208  ��stanbul
# 9545        5915054                  Baltazar           208  ��stanbul
# 9546        5915730               Naml۱ Gurme           208  ��stanbul
# 9547        5908749              Ceviz A��ac۱           208  ��stanbul
# 9548        5915807                     Huqqa           208  ��stanbul
# 9549        5916112               A���k Kahve           208  ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ��stanbul
#
#                                                 Address         Locality  \
# 9541  Emirgan Mahallesi, Sak۱p Sabanc۱ Caddesi, No 4...         Emirg��n
# ...

# %%
data[data==0].count()
# Out:
# Restaurant ID              0
# Restaurant Name            0
# Country Code               0
# City                       0
# Address                    0
# Locality                   0
# Locality Verbose           0
# Longitude                498
# Latitude                 498
# Cuisines                   0
# Average Cost for two      18
# Currency                   0
# Has Table booking          0
# Has Online delivery        0
# Is delivering now          0
# Switch to order menu       0
# Price range                0
# Aggregate rating        2148
# Rating color               0
# Rating text                0
# Votes                   1094
# dtype: int64

# %%
data.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
data.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
data=data.fillna('unknown')

# %%
data.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
col_list=data.columns.tolist()
print("Columns in the Dataset are : ", col_list)
# Out:
# Columns in the Dataset are :  ['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address', 'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines', 'Average Cost for two', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Switch to order menu', 'Price range', 'Aggregate rating', 'Rating color', 'Rating text', 'Votes']

# %%
data1=data[['Restaurant ID','Restaurant Name','Country Code','City','Address']]

# %%
data1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
non_numeric_columns=data.select_dtypes(exclude=['float64','int64']).columns
print("Non-numeric Columns in dataset : ",non_numeric_columns)
# Out:
# Non-numeric Columns in dataset :  Index(['Restaurant Name', 'City', 'Address', 'Locality', 'Locality Verbose',
#        'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery',
#        'Is delivering now', 'Switch to order menu', 'Rating color',
#        'Rating text'],
#       dtype='object')

# %%
data=data.drop("Cuisines",axis=1)

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
#encoding categorical data using one-hot encoding
# Assign the desired DataFrame to the variable 'x'
x = data.drop("Aggregate rating", axis=1) # Assuming 'Aggregate rating' is the target variable
x_encode = pd.get_dummies(x, drop_first=True)

# %%
#encoding categorical data using one-hot encoding
x_encode=pd.get_dummies(x,drop_first=True)

# %%
from sklearn.model_selection import train_test_split

# %%
x=data.drop("Aggregate rating",axis=1)
y=data["Aggregate rating"]

# %%
x
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
y
# Out:
# 0       4.8
# 1       4.5
# 2       4.4
# 3       4.9
# 4       4.8
#        ...
# 9546    4.1
# 9547    4.2
# 9548    3.7
# 9549    4.0
# 9550    4.0
# Name: Aggregate rating, Length: 9551, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x_encode,y,test_size=0.25,random_state=0)

# %%
x_train
# Out:
#       Restaurant ID  Country Code  Longitude   Latitude  Average Cost for two  \
# 785         2900012             1  85.818494  20.292363                  1500
# 6883       18414500             1   0.000000   0.000000                   300
# 7319         307418             1  77.223136  28.571265                   600
# 1142         130275             1  73.743606  15.585658                  1100
# 2916       18239781             1  77.248612  28.540084                   300
# ...             ...           ...        ...        ...                   ...
# 7891         300461             1  77.079268  28.638455                   300
# 9225        3200015             1  73.169083  22.310329                   600
# 4859       18410302             1   0.000000   0.000000                   500
# 3264         303215             1  77.230681  28.573417                   200
# 2732       18216896             1  77.178217  28.693567                   550
#
# ...

# %%
x_test
# Out:
#       Restaurant ID  Country Code  Longitude   Latitude  Average Cost for two  \
# 1746       18471259             1  77.048274  28.472892                   600
# 3034             66             1  77.221003  28.633679                  2000
# 1638       18391159             1  77.097590  28.451147                   600
# 6078       18231755             1  77.081809  28.599076                   200
# 5584       18449786             1  77.218771  28.709168                   100
# ...             ...           ...        ...        ...                   ...
# 1888         313456             1   0.000000   0.000000                   350
# 7014       18355138             1  77.168557  28.587647                   300
# 5845           5528             1  77.251516  28.547879                   150
# 5432           3207             1  77.220222  28.529549                  2000
# 6314         307444             1  77.135978  28.683691                   500
#
# ...

# %%
y_test
# Out:
# 1746    3.1
# 3034    3.5
# 1638    3.7
# 6078    0.0
# 5584    0.0
#        ...
# 1888    3.1
# 7014    3.7
# 5845    0.0
# 5432    3.4
# 6314    2.4
# Name: Aggregate rating, Length: 2388, dtype: float64

# %%
y_train
# Out:
# 785     4.3
# 6883    0.0
# 7319    2.3
# 1142    4.8
# 2916    3.1
#        ...
# 7891    3.4
# 9225    4.0
# 4859    0.0
# 3264    4.0
# 2732    2.5
# Name: Aggregate rating, Length: 7163, dtype: float64

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model=DecisionTreeRegressor()

# %%
#Training the model
model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([3. , 3.9, 3.6, ..., 0. , 3.4, 2.3])

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
#mean_squared_error
print("Mean Squared Error : ",mean_squared_error(y_test,y_pred))
# Out:
# Mean Squared Error :  0.05202261306532663

# %%
#r2_score
print("R2 Score : ",r2_score(y_test,y_pred))
# Out:
# R2 Score :  0.977237051942022

# %%
#mean_absolute_error
print("Mean Absolute Error : ",mean_absolute_error(y_test,y_pred))
# Out:
# Mean Absolute Error :  0.14082914572864322

# %%
#root_mean_squared_error
print("Root Mean Squared Error : ",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# Root Mean Squared Error :  0.2280846620562782

# %%
importance= model.feature_importances_
feature_names=x_encode.columns

# %%
#generating table for feature , importance and rating
feature_importance= pd.DataFrame({"Feature": feature_names,"Importance":importance})

# %%
feature_importance
# Out:
#                      Feature  Importance
# 0              Restaurant ID    0.002040
# 1               Country Code    0.000021
# 2                  Longitude    0.001394
# 3                   Latitude    0.001201
# 4       Average Cost for two    0.000769
# ...                      ...         ...
# 18999  Rating text_Excellent    0.000000
# 19000       Rating text_Good    0.013080
# 19001  Rating text_Not rated    0.000000
# 19002       Rating text_Poor    0.000000
# 19003  Rating text_Very Good    0.000000
#
# [19004 rows x 2 columns]

# %%
#sorted order of influential features
sorted_important_features=feature_importance.sort_values(by="Importance",ascending=False)

# %%
sorted_important_features
# Out:
#                                                  Feature    Importance
# 6                                                  Votes  9.002944e-01
# 18995                                Rating color_Orange  5.175303e-02
# 18996                                   Rating color_Red  2.065217e-02
# 19000                                   Rating text_Good  1.308016e-02
# 18994                                 Rating color_Green  2.608169e-03
# ...                                                  ...           ...
# 6341                          Restaurant Name_Tasty Fare -3.229410e-19
# 1728                    Restaurant Name_Colonel's Kababz -3.229410e-19
# 8102   Address_13/13, Sardar Patel Marg, Civil Lines,... -3.229410e-19
# 1829                    Restaurant Name_Curry N' Tandoor -6.458821e-19
# 16848                          Locality_Fraser Road Area -3.767645e-18
#
# [19004 rows x 2 columns]
